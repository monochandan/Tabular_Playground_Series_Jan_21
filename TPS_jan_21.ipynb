# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
os.getcwd()
# Out:
# 'c:\\Users\\looka\\OneDrive\\Documents\\Python\\python\\Keggle\\Tabular Playground Series Jan 2021'

# %%
df_train = pd.read_csv('train.csv')
df_test  = pd.read_csv('test.csv')

# %%
print(df_train['target'].unique()) ### feature dimension
# Out:
# [7.24304259 8.20333114 7.77609076 ... 9.59248653 8.2079506  8.89028481]

# %%
df_train.head(5)
# Out:
#    id     cont1     cont2     cont3     cont4     cont5     cont6     cont7  \
# 0   1  0.670390  0.811300  0.643968  0.291791  0.284117  0.855953  0.890700
# 1   3  0.388053  0.621104  0.686102  0.501149  0.643790  0.449805  0.510824
# 2   4  0.834950  0.227436  0.301584  0.293408  0.606839  0.829175  0.506143
# 3   5  0.820708  0.160155  0.546887  0.726104  0.282444  0.785108  0.752758
# 4   8  0.935278  0.421235  0.303801  0.880214  0.665610  0.830131  0.487113
#
#       cont8     cont9    cont10    cont11    cont12    cont13    cont14  \
# 0  0.285542  0.558245  0.779418  0.921832  0.866772  0.878733  0.305411
# 1  0.580748  0.418335  0.432632  0.439872  0.434971  0.369957  0.369484
# 2  0.558771  0.587603  0.823312  0.567007  0.677708  0.882938  0.303047
# 3  0.823267  0.574466  0.580843  0.769594  0.818143  0.914281  0.279528
# 4  0.604157  0.874658  0.863427  0.983575  0.900464  0.935918  0.435772
#
#      target
# 0  7.243043
# 1  8.203331
# 2  7.776091
# 3  6.957716
# ...

# %%
print(df_train.isnull().sum())
# Out:
# id        0
# cont1     0
# cont2     0
# cont3     0
# cont4     0
# cont5     0
# cont6     0
# cont7     0
# cont8     0
# cont9     0
# cont10    0
# cont11    0
# cont12    0
# cont13    0
# cont14    0
# target    0
# dtype: int64

# %%
df_train.describe()
# Out:
#                   id          cont1          cont2          cont3  \
# count  300000.000000  300000.000000  300000.000000  300000.000000
# mean   249825.145857       0.506873       0.497898       0.521557
# std    144476.732562       0.203976       0.228159       0.200770
# min         1.000000      -0.082263      -0.031397       0.020967
# 25%    124656.500000       0.343078       0.319170       0.344096
# 50%    249738.500000       0.484005       0.553209       0.551471
# 75%    374836.250000       0.643789       0.731263       0.648315
# max    499999.000000       1.016227       0.859697       1.006955
#
#                cont4          cont5          cont6          cont7  \
# count  300000.000000  300000.000000  300000.000000  300000.000000
# mean        0.515683       0.502022       0.526515       0.487890
# std         0.233035       0.220701       0.217909       0.181096
# min         0.152761       0.276377       0.066166      -0.097666
# ...

# %%
df_train.drop(['id'], axis=1, inplace = True)
df_test.drop(['id'], axis=1, inplace = True)

# %%
f,ax = plt.subplots(figsize= (9,8))
sns.distplot(df_train['target'], color = 'r')
#ax.xaxis.grid(True)
ax.set(xlabel='Target')
ax.set(ylabel='value')
ax.set_title('target value distribution')
plt.show()
# Out:
# C:\Users\looka\AppData\Roaming\Python\Python310\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
f,ax = plt.subplots(figsize= (9,8))
sns.distplot(df_train['target'], color = 'r')
#ax.xaxis.grid(True)
ax.set(xlabel='Target')
ax.set(ylabel='value')
ax.set_title('target value distribution')
plt.show()
# Out:
# C:\Users\looka\AppData\Roaming\Python\Python310\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
features = [f'cont{x}' for x in range(1, 14)] ### creating feature array with column names
features
# Out:
# ['cont1',
#  'cont2',
#  'cont3',
#  'cont4',
#  'cont5',
#  'cont6',
#  'cont7',
#  'cont8',
#  'cont9',
#  'cont10',
#  'cont11',
#  'cont12',
#  'cont13']

# %%
# check linear or nonlinear relationship
# i = 1
# plt.figure()
# fig, ax = plt.subplots(5, 3, figsize = (14, 24))
# for feature in features:
#     #if feature == "cont6" or feature == "cont11" or feature == "cont12" or feature == "cont13":
#     plt.subplot(5,3,i) ## subplot(nrows----5, ncols---3, index---i, **kwargs)
#     sns.distplot(df_train[feature], color = 'red', kde = 'True', bins = 120, label = 'train')
#     sns.distplot(df_test[feature], color = 'green', kde = 'True', bins = 120, label = 'test')
#     plt.xlabel(feature, fontsize = 9);
#     plt.legend()
#     i += 1

# plt.show()
# g = sns.PairGrid(df_train)
# g.map(sns.scatterplot)

# g = sns.FacetGrid(df_train['target'], col=df_train['cont1'])
# g.map(sns.scatterplot, "target", "Cont1", alpha=.7)
# g.add_legend()
i = 1
plt.figure()
fig, ax = plt.subplots(5, 3, figsize = (14, 24))

for feature in features:
    plt.subplot(5,3,i)
    sns.scatterplot(x = df_train[feature], y = df_train['target'], data = df_train)
    plt.xlabel(feature, fontsize = 9)
    plt.legend()
    i = i + 1
#sns.lineplot(x=df_train['cont1'], y=df_train['target'], data=df_train, color="red", ci=None)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %%
### how feature distribution varies for each column 
i = 1
plt.figure()
fig, ax = plt.subplots(5, 3, figsize = (14, 24))
for feature in features:
    #if feature == "cont6" or feature == "cont11" or feature == "cont12" or feature == "cont13":
    plt.subplot(5,3,i) ## subplot(nrows----5, ncols---3, index---i, **kwargs)
    sns.distplot(df_train[feature], color = 'red', kde = 'True', bins = 120, label = 'train')
    sns.distplot(df_test[feature], color = 'green', kde = 'True', bins = 120, label = 'test')
    plt.xlabel(feature, fontsize = 9);
    plt.legend()
    i += 1

plt.show()

### feature 6, 11, 12, 13 are quite similer pattern showing
# Out:
# C:\Users\looka\AppData\Roaming\Python\Python310\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\looka\AppData\Roaming\Python\Python310\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
df_train.corr()
# Out:
#            cont1     cont2     cont3     cont4     cont5     cont6     cont7  \
# cont1   1.000000 -0.080170 -0.419712  0.273705 -0.059012  0.698556  0.341478
# cont2  -0.080170  1.000000  0.334487 -0.005533  0.150737  0.023692  0.116222
# cont3  -0.419712  0.334487  1.000000 -0.329131  0.060931 -0.300509  0.106904
# cont4   0.273705 -0.005533 -0.329131  1.000000  0.123526  0.152752 -0.077045
# cont5  -0.059012  0.150737  0.060931  0.123526  1.000000 -0.179084 -0.241272
# cont6   0.698556  0.023692 -0.300509  0.152752 -0.179084  1.000000  0.541975
# cont7   0.341478  0.116222  0.106904 -0.077045 -0.241272  0.541975  1.000000
# cont8   0.373340  0.081049 -0.309783  0.324784  0.010438  0.415008  0.150403
# cont9   0.794003 -0.046769 -0.406743  0.261927 -0.071764  0.716613  0.341759
# cont10  0.725040  0.035101 -0.289756  0.204139 -0.102531  0.770628  0.465418
# cont11  0.565717  0.126024 -0.075415  0.063961 -0.222244  0.737495  0.672188
# ...

# %%
### visualize the cor relation between neumerical veriables
corr = df_train.corr()
plt.subplots(figsize = (14, 10))
sns.heatmap(corr, vmax = 0.9, cmap = 'inferno', square = 'True') ###

### have multi-colinearity from col7 to col9.. but its not problem if we dont care about individuals contribuiton / weights
# Out:
# <AxesSubplot:>

# %%
corr = df_test.corr()
plt.subplots(figsize = (14, 10))
sns.heatmap(corr, vmax = 0.9, cmap = 'inferno', square = 'True') ###
# Out:
# <AxesSubplot:>

# %%
### box plot for outliers
# i = 1
# plt.figure()
# fig, ax = plt.subplots(5, 3, figsize = (14, 24))
# for feature in features:
#     #if feature == "cont6" or feature == "cont11" or feature == "cont12" or feature == "cont13":
#     plt.subplot(5,3,i) ## subplot(nrows----5, ncols---3, index---i, **kwargs)
#     sns.distplot(df_train[feature], color = 'red', kde = 'True', bins = 120, label = 'train')
#     sns.distplot(df_test[feature], color = 'green', kde = 'True', bins = 120, label = 'test')
#     plt.xlabel(feature, fontsize = 9);
#     plt.legend()
#     i += 1
# plt.show()
i = 1
plt.figure()
fig, ax = plt.subplots(5,3, figsize = (14, 24))
#plt.subplots(figsize=(20,10))
for col in df_train.columns[:-1]: ### not taking target column
    plt.subplot(5,3,i)
    plt.boxplot([df_train[col], df_test[col]], labels = ['train', 'test'])
    plt.title(col)
    plt.legend()
    #plt.show()
    i += 1
plt.show()

### in col7 and col9 have some outliers
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %%
plt.boxplot(df_train['target'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fcca0f7bb0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fcca0f4400>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fcca0f6aa0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fcca0f7040>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fcca0f5600>],
#  'means': []}

# %%
### replace outliers by median value
def replace_outliers(data):
    for col in data.columns:
        Q1 = data[col].quantile(0.25)
        Q3 = data[col].quantile(0.75)
        IQR = Q1 - Q3
        median_ = data[col].median()
        data.loc[((data[col]< Q1 - 1.5*IQR ) | (data[col] > Q1 - 1.5*IQR )), col] = median_ ## if value is outside of the interquertile range replace by the median value
        
    return data

# %%
df_train = replace_outliers(df_train)
df_test = replace_outliers(df_test)

# %%
x = df_train.drop(['target'], axis = 1)
y = df_train.target

# %%
y.head()
# Out:
# 0    7.940571
# 1    7.940571
# 2    7.940571
# 3    7.940571
# 4    7.940571
# Name: target, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.18, random_state = 33)

# %% [markdown]
# GRIDSEARCHCV  used for select best value for hyperparameters

# %%
import lightgbm as lgb
LGB = lgb.LGBMRegressor(random_state = 33, n_estimators=4800, min_data_oer_group = 5, boosting_type = 'gbdt', num_leaves=246,
                        max_dept = -1, learning_rate = 0.005, subsample_for_bin = 200000,
                        lambda_l1 = 1.074622455507616e-05, lambda_l2 = 2.0521330798729704e-06,
                        n_jobs = -1, cat_smooth = 1.0, importance_type = 'split', metric = 'rmse', min_child_samples = 20, min_gain_to_split = 0.0,
                        feature_fraction = 0.5, bagging_freq = 6, min_sum_hessian_in_leaf = 0.001,  min_data_in_leaf = 100, bagging_fraction= 0.82063411)
LGB.fit(x_train,y_train)
# Out:
# [LightGBM] [Warning] Unknown parameter: max_dept
# [LightGBM] [Warning] Unknown parameter: min_data_oer_group
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] min_gain_to_split is set=0.0, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.0
# [LightGBM] [Warning] lambda_l1 is set=1.074622455507616e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.074622455507616e-05
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=0.001, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=0.001
# [LightGBM] [Warning] lambda_l2 is set=2.0521330798729704e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.0521330798729704e-06
# ...

# %%
pred_LGB = LGB.predict(x_test)
# Out:
# [LightGBM] [Warning] Unknown parameter: max_dept
# [LightGBM] [Warning] Unknown parameter: min_data_oer_group
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] min_gain_to_split is set=0.0, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.0
# [LightGBM] [Warning] lambda_l1 is set=1.074622455507616e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.074622455507616e-05
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=0.001, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=0.001
# [LightGBM] [Warning] lambda_l2 is set=2.0521330798729704e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.0521330798729704e-06
# ...

# %%
from sklearn.metrics import mean_squared_error
mse_LGB = np.sqrt(mean_squared_error(y_test, pred_LGB))
mse_LGB
# Out:
# 1.6092525711997038e-07

# %%
pred_LGB = LGB.predict(df_test)
pred_LGB
# Out:
# [LightGBM] [Warning] Unknown parameter: max_dept
# [LightGBM] [Warning] Unknown parameter: min_data_oer_group
# [LightGBM] [Warning] min_data_in_leaf is set=100, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=100
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] min_gain_to_split is set=0.0, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.0
# [LightGBM] [Warning] lambda_l1 is set=1.074622455507616e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.074622455507616e-05
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=0.001, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=0.001
# [LightGBM] [Warning] lambda_l2 is set=2.0521330798729704e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.0521330798729704e-06
# ...

# %%
output = pd.DataFrame({'id': df_test.id, 'target': pred_LGB})
#output.to_csv('Kaggle_Playground_Submission.csv', index = False)

# %%
output.head(5)
# Out:
#    id    target
# 0   0  7.940571
# 1   2  7.940571
# 2   6  7.940571
# 3   7  7.940571
# 4  10  7.940571
